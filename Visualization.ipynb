# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data/the_data_we_work_with.csv')
tourism = df

df['total_cost_EUR'] = df['total_cost']*0.00036
df.sort_values('total_cost_EUR', ascending=False)
# Out:
#              country age_group          travel_with  total_female  total_male
# 3370    SOUTH AFRICA     25-44    Friends/Relatives           2.0         2.0  \
# 2790    SOUTH AFRICA     25-44    Friends/Relatives           1.0         1.0
# 1710           ITALY     45-64    Friends/Relatives           2.0         4.0
# 387           CANADA     25-44  Spouse and Children           1.0         3.0
# 1782  UNITED KINGDOM      1-24    Friends/Relatives           4.0         3.0
# ...              ...       ...                  ...           ...         ...
# 4027           JAPAN      1-24                Alone           1.0         0.0
# 3662  UNITED KINGDOM     25-44             Children           1.0         2.0
# 4328        ZIMBABWE     25-44                Alone           0.0         1.0
# 4367          RWANDA     25-44    Friends/Relatives           2.0         0.0
# 4449         BURUNDI     25-44                Alone           0.0         1.0
#
# ...

# %%
df.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar
# count   4759.000000  4759.000000     4759.000000     4759.000000  \
# mean       0.920782     1.008825        8.489809        2.297752
# std        1.267926     1.137243       10.455949        4.214336
# min        0.000000     0.000000        0.000000        0.000000
# 25%        0.000000     1.000000        3.000000        0.000000
# 50%        1.000000     1.000000        6.000000        0.000000
# 75%        1.000000     1.000000       11.000000        4.000000
# max       49.000000    44.000000      145.000000       61.000000
#
#          total_cost  total_cost_EUR
# count  4.759000e+03     4759.000000
# mean   8.055908e+06     2900.126906
# std    1.210523e+07     4357.883092
# min    4.900000e+04       17.640000
# 25%    7.942655e+05      285.935580
# 50%    3.315000e+06     1193.400000
# 75%    9.791378e+06     3524.896008
# max    9.953288e+07    35831.835000

# %%
df.plot(y='total_cost_EUR', use_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.plot.scatter(y='total_cost_EUR', use_index=True)
#
# TypeError: PlotAccessor.scatter() missing 1 required positional argument: 'x'

# %%
#sns.histplot(data = df.reset_index(), kde=True, stat='density', x = 'total_cost_EUR')
sns.boxplot(x='total_cost_EUR', data=df.reset_index())
# Out:
# <Axes: xlabel='total_cost_EUR'>
